# %% [markdown]
# # Classificação de sinais de trânsito

# %% [markdown]
# Arquitetura LeNet: http://yann.lecun.com/exdb/publis/pdf/lecun-01a.pdf

# %% [markdown]
# # Etapa 1: Importação das bibliotecas

# %%
# !pip install matplotlib --upgrade
# !pip install numpy --upgrade
# !pip install pandas --upgrade
# !pip install seaborn --upgrade
# !pip install tensorflow --upgrade
# Out:
# Requirement already satisfied: matplotlib in /home/ledragox/anaconda3/lib/python3.9/site-packages (3.5.1)
# Requirement already satisfied: cycler>=0.10 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ledragox/.local/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: numpy>=1.17 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.21.4)
# Requirement already satisfied: pillow>=6.2.0 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from matplotlib) (21.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: six in /home/ledragox/anaconda3/lib/python3.9/site-packages (from cycler>=0.10->matplotlib) (1.16.0)
# Requirement already satisfied: numpy in /home/ledragox/anaconda3/lib/python3.9/site-packages (1.21.4)
# Requirement already satisfied: pandas in /home/ledragox/anaconda3/lib/python3.9/site-packages (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from pandas) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/ledragox/.local/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from pandas) (1.21.4)
# Requirement already satisfied: six>=1.5 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Requirement already satisfied: seaborn in /home/ledragox/anaconda3/lib/python3.9/site-packages (0.11.2)
# Requirement already satisfied: scipy>=1.0 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from seaborn) (1.7.1)
# Requirement already satisfied: pandas>=0.23 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from seaborn) (1.3.5)
# Requirement already satisfied: matplotlib>=2.2 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from seaborn) (3.5.1)
# Requirement already satisfied: numpy>=1.15 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from seaborn) (1.21.4)
# Requirement already satisfied: packaging>=20.0 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (21.0)
# Requirement already satisfied: cycler>=0.10 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ledragox/.local/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: six in /home/ledragox/anaconda3/lib/python3.9/site-packages (from cycler>=0.10->matplotlib>=2.2->seaborn) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from pandas>=0.23->seaborn) (2021.3)
# Requirement already satisfied: tensorflow in /home/ledragox/anaconda3/lib/python3.9/site-packages (2.7.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: six>=1.12.0 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: numpy>=1.14.5 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.21.4)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.21.0 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from tensorflow) (0.22.0)
# Requirement already satisfied: gast<0.5.0,>=0.2.1 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: tensorboard~=2.6 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from tensorflow) (2.7.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.42.0)
# Requirement already satisfied: libclang>=9.0.1 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from tensorflow) (12.0.0)
# Requirement already satisfied: absl-py>=0.4.0 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.0.0)
# Requirement already satisfied: tensorflow-estimator<2.8,~=2.7.0rc0 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from tensorflow) (2.7.0)
# Requirement already satisfied: protobuf>=3.9.2 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from tensorflow) (3.19.1)
# Requirement already satisfied: termcolor>=1.1.0 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: keras<2.8,>=2.7.0rc0 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from tensorflow) (2.7.0)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from tensorflow) (0.37.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from tensorflow) (2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from tensorflow) (3.10.0.2)
# Requirement already satisfied: h5py>=2.9.0 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from tensorboard~=2.6->tensorflow) (2.3.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from tensorboard~=2.6->tensorflow) (0.4.6)
# Requirement already satisfied: setuptools>=41.0.0 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from tensorboard~=2.6->tensorflow) (58.0.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from tensorboard~=2.6->tensorflow) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from tensorboard~=2.6->tensorflow) (1.8.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from tensorboard~=2.6->tensorflow) (3.3.6)
# Requirement already satisfied: werkzeug>=0.11.15 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from tensorboard~=2.6->tensorflow) (2.0.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from tensorboard~=2.6->tensorflow) (2.26.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.6->tensorflow) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (0.4.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (3.2)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/ledragox/anaconda3/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (3.1.1)

# %%
import zipfile
import random
from tensorflow.keras import layers
import tensorflow as tf
import seaborn as sns
import PIL
import pickle
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
# %tensorflow_version 2.x
tf.__version__
# Out:
# UsageError: Line magic function `%tensorflow_version` not found.

# %% [markdown]
# # Etapa 2: Importação da base de dados

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
path = 'data/traffic-signs-data.zip'
zip_object = zipfile.ZipFile(file=path, mode='r')
zip_object.extractall('./data')
zip_object.close()

# %%
with open('data/traffic-signs-data/train.p', mode='rb') as training_data:
    train = pickle.load(training_data)
with open('data/traffic-signs-data/test.p', mode='rb') as testing_data:
    test = pickle.load(testing_data)
with open('data/traffic-signs-data/valid.p', mode='rb') as validation_data:
    valid = pickle.load(validation_data)

# %%
train
# Out:
# {'coords': array([[  6,   5,  21,  20],
#         [  6,   6,  22,  22],
#         [  5,   6,  22,  23],
#         ...,
#         [ 17,  15, 178, 155],
#         [ 17,  15, 183, 160],
#         [ 20,  18, 211, 184]], dtype=uint8),
#  'labels': array([41, 41, 41, ..., 25, 25, 25], dtype=uint8),
#  'features': array([[[[ 28,  25,  24],
#           [ 27,  24,  23],
#           [ 27,  24,  22],
#           ...,
#           [ 32,  28,  24],
#           [ 31,  27,  25],
#           [ 31,  27,  26]],
#
#          [[ 29,  26,  25],
#           [ 27,  25,  23],
#           [ 27,  25,  23],
#           ...,
#           [ 32,  28,  24],
#           [ 31,  27,  24],
#           [ 30,  27,  25]],
#
#          [[ 28,  26,  26],
#           [ 27,  25,  23],
#           [ 26,  25,  23],
#           ...,
#           [ 32,  28,  24],
#           [ 31,  27,  24],
#           [ 30,  27,  25]],
#
#          ...,
#
#          [[ 27,  24,  23],
#           [ 28,  25,  24],
#           [ 30,  25,  24],
#           ...,
#           [ 27,  24,  23],
#           [ 28,  24,  22],
#           [ 29,  25,  22]],
#
#          [[ 28,  23,  23],
#           [ 29,  24,  24],
#           [ 31,  25,  24],
#           ...,
#           [ 27,  24,  23],
#           [ 28,  24,  22],
#           [ 28,  24,  21]],
#
#          [[ 29,  23,  23],
#           [ 30,  24,  24],
#           [ 32,  24,  23],
#           ...,
#           [ 27,  24,  22],
#           [ 27,  23,  21],
#           [ 26,  22,  20]]],
#
#
#         [[[ 28,  24,  24],
#           [ 26,  23,  23],
#           [ 27,  24,  24],
#           ...,
#           [ 31,  28,  26],
#           [ 31,  28,  27],
#           [ 32,  28,  27]],
#
#          [[ 27,  24,  24],
#           [ 27,  24,  24],
#           [ 28,  25,  24],
#           ...,
#           [ 31,  27,  25],
#           [ 31,  27,  26],
#           [ 33,  29,  27]],
#
#          [[ 26,  24,  24],
#           [ 26,  24,  24],
#           [ 27,  24,  23],
#           ...,
#           [ 31,  26,  25],
#           [ 31,  27,  26],
#           [ 33,  29,  27]],
#
#          ...,
#
#          [[ 28,  25,  23],
#           [ 30,  27,  24],
#           [ 30,  27,  24],
#           ...,
#           [ 27,  24,  22],
#           [ 27,  24,  22],
#           [ 28,  24,  22]],
#
#          [[ 27,  24,  22],
#           [ 29,  26,  23],
#           [ 31,  26,  24],
#           ...,
#           [ 26,  23,  21],
#           [ 27,  24,  22],
#           [ 28,  25,  23]],
#
#          [[ 28,  24,  23],
#           [ 28,  24,  22],
#           [ 29,  24,  22],
#           ...,
#           [ 27,  23,  22],
#           [ 27,  24,  23],
#           [ 29,  26,  25]]],
#
#
#         [[[ 29,  25,  25],
#           [ 29,  26,  26],
#           [ 30,  27,  27],
#           ...,
#           [ 31,  27,  24],
#           [ 31,  28,  25],
#           [ 32,  29,  27]],
#
#          [[ 27,  24,  24],
#           [ 27,  25,  25],
#           [ 28,  26,  26],
#           ...,
#           [ 31,  27,  23],
#           [ 32,  28,  25],
#           [ 33,  30,  27]],
#
#          [[ 27,  24,  24],
#           [ 28,  26,  26],
#           [ 29,  27,  27],
#           ...,
#           [ 32,  28,  24],
#           [ 32,  28,  24],
#           [ 33,  29,  26]],
#
#          ...,
#
#          [[ 28,  26,  22],
#           [ 29,  26,  21],
#           [ 31,  26,  22],
#           ...,
#           [ 29,  24,  21],
#           [ 28,  23,  20],
#           [ 28,  23,  22]],
#
#          [[ 27,  26,  23],
#           [ 28,  25,  21],
#           [ 30,  25,  22],
#           ...,
#           [ 28,  23,  21],
#           [ 27,  22,  20],
#           [ 28,  24,  22]],
#
#          [[ 29,  26,  23],
#           [ 28,  24,  21],
#           [ 29,  24,  21],
#           ...,
#           [ 29,  25,  23],
#           [ 28,  24,  22],
#           [ 30,  26,  24]]],
#
#
#         ...,
#
#
#         [[[ 51,  67,  86],
#           [ 55,  59,  71],
#           [ 75,  81,  92],
#           ...,
#           [250, 248, 243],
#           [207, 212, 233],
#           [121, 116, 140]],
#
#          [[ 35,  42,  49],
#           [ 48,  47,  51],
#           [ 91,  96, 113],
#           ...,
#           [220, 224, 226],
#           [169, 177, 187],
#           [ 84,  87, 100]],
#
#          [[ 27,  26,  29],
#           [ 41,  38,  39],
#           [ 55,  64,  78],
#           ...,
#           [122, 143, 160],
#           [ 97, 104, 129],
#           [ 59,  59,  56]],
#
#          ...,
#
#          [[ 24,  23,  27],
#           [ 21,  20,  27],
#           [ 20,  19,  22],
#           ...,
#           [ 76,  79,  83],
#           [ 54,  64,  77],
#           [ 45,  51,  65]],
#
#          [[ 31,  31,  33],
#           [ 22,  23,  29],
#           [ 20,  18,  21],
#           ...,
#           [ 66,  67,  84],
#           [ 56,  65,  74],
#           [ 45,  55,  73]],
#
#          [[ 28,  28,  30],
#           [ 22,  21,  25],
#           [ 19,  18,  19],
#           ...,
#           [ 67,  63,  76],
#           [ 39,  45,  55],
#           [ 32,  37,  47]]],
#
#
#         [[[ 82,  78,  96],
#           [120, 126, 148],
#           [112, 125, 146],
#           ...,
#           [185, 182, 177],
#           [204, 210, 215],
#           [132, 114, 121]],
#
#          [[ 74,  77,  93],
#           [171, 174, 185],
#           [137, 164, 184],
#           ...,
#           [180, 181, 187],
#           [198, 200, 213],
#           [ 79,  85,  85]],
#
#          [[ 54,  50,  56],
#           [100, 106, 118],
#           [117, 132, 158],
#           ...,
#           [157, 153, 160],
#           [176, 183, 199],
#           [ 88,  80,  82]],
#
#          ...,
#
#          [[ 22,  21,  22],
#           [ 20,  19,  19],
#           [ 18,  16,  19],
#           ...,
#           [ 50,  50,  60],
#           [ 37,  43,  52],
#           [ 30,  41,  59]],
#
#          [[ 18,  16,  18],
#           [ 19,  17,  18],
#           [ 19,  18,  21],
#           ...,
#           [ 36,  44,  60],
#           [ 33,  36,  48],
#           [ 36,  43,  61]],
#
#          [[ 18,  17,  20],
#           [ 21,  20,  23],
#           [ 24,  22,  25],
#           ...,
#           [ 32,  34,  41],
#           [ 45,  42,  48],
#           [ 41,  43,  52]]],
#
#
#         [[[ 69,  79,  96],
#           [ 24,  26,  28],
#           [ 40,  42,  45],
#           ...,
#           [225, 234, 237],
#           [151, 161, 166],
#           [164, 162, 169]],
#
#          [[ 99, 110, 125],
#           [ 36,  41,  47],
#           [ 63,  56,  62],
#           ...,
#           [197, 216, 224],
#           [154, 163, 169],
#           [164, 163, 159]],
#
#          [[104, 107, 113],
#           [ 34,  37,  40],
#           [ 72,  70,  77],
#           ...,
#           [223, 237, 235],
#           [181, 192, 198],
#           [166, 167, 159]],
#
#          ...,
#
#          [[ 21,  20,  23],
#           [ 23,  24,  30],
#           [ 19,  20,  24],
#           ...,
#           [ 45,  47,  54],
#           [ 58,  62,  70],
#           [ 58,  70,  82]],
#
#          [[ 18,  17,  21],
#           [ 19,  19,  24],
#           [ 18,  18,  23],
#           ...,
#           [ 36,  36,  40],
#           [ 58,  59,  70],
#           [ 61,  69,  81]],
#
#          [[ 17,  16,  19],
#           [ 16,  15,  18],
#           [ 16,  15,  18],
#           ...,
#           [ 40,  40,  44],
#           [ 57,  62,  73],
#           [ 57,  68,  80]]]], dtype=uint8),
#  'sizes': array([[ 26,  25],
#         [ 27,  27],
#         [ 27,  28],
#         ...,
#         [194, 169],
#         [201, 175],
#         [230, 201]], dtype=uint8)}

# %%
X_train, y_train = train['features'], train['labels']
X_test, y_test = test['features'], test['labels']
X_validation, y_validation = valid['features'], valid['labels']

# %%
print(X_train.shape, "\n", y_train.shape)
# Out:
# (34799, 32, 32, 3)
#  (34799,)

# %%
X_test.shape
# Out:
# (12630, 32, 32, 3)

# %%
X_validation.shape
# Out:
# (4410, 32, 32, 3)

# %% [markdown]
# # Etapa 3: Visualização dos dados

# %%
i = random.randint(1, 34799)
plt.imshow(X_train[i])
y_train[i]
# Out:
# 25

# %%
i = random.randint(1, 12630)
plt.imshow(X_test[i])
y_test[i]
# Out:
# 13

# %%
i = random.randint(1, 4410)
plt.imshow(X_validation[i])
y_validation[i]
# Out:
# 22

# %% [markdown]
# # Etapa 4: Preparação dos dados

# %%
from sklearn.utils import shuffle
X_train, y_train = shuffle(X_train, y_train)

# %%
X_train_gray = np.sum(X_train / 3, axis=3, keepdims=True)
X_test_gray = np.sum(X_test / 3, axis=3, keepdims=True)
X_validation_gray = np.sum(X_validation / 3, axis=3, keepdims=True)

# %%
X_train_gray.shape
# Out:
# (34799, 32, 32, 1)

# %%
X_test_gray.shape
# Out:
# (12630, 32, 32, 1)

# %%
X_validation_gray.shape
# Out:
# (4410, 32, 32, 1)

# %%
X_train_gray_norm = (X_train_gray - 128) / 128
X_test_gray_norm = (X_test_gray - 128) / 128
X_validation_gray_norm = (X_validation_gray - 128) / 128

# %%
np.max(X_train_gray_norm)
# Out:
# 0.9921875

# %%
np.min(X_train_gray_norm)
# Out:
# -0.9713541666666666

# %%
i = random.randint(1, 34799)
plt.imshow(X_train_gray[i].squeeze(), cmap='gray')
plt.figure()
plt.imshow(X_train[i])
plt.figure()
plt.imshow(X_train_gray_norm[i].squeeze(), cmap='gray')

# %%
i = random.randint(1, 12630)
plt.imshow(X_test_gray[i].squeeze(), cmap='gray')
plt.figure()
plt.imshow(X_test[i])
plt.figure()
plt.imshow(X_test_gray_norm[i].squeeze(), cmap='gray')

# %%
i = random.randint(1, 4410)
plt.imshow(X_validation_gray[i].squeeze(), cmap='gray')
plt.figure()
plt.imshow(X_validation[i])
plt.figure()
plt.imshow(X_validation_gray_norm[i].squeeze(), cmap='gray')

# %% [markdown]
# # Etapa 5: Criação do modelo e treinamento

# %% [markdown]
# ![lenet5.png](data:image/png;base64,...)

# %%
from tensorflow.keras import layers, models

# %%
LeNet = models.Sequential()
# Out:
# 2021-12-16 11:19:16.509698: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-16 11:19:16.806469: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-16 11:19:16.806784: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-16 11:19:16.807607: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-12-16 11:19:16.808385: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-16 11:19:16.808629: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-16 11:19:16.808869: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-16 11:19:18.217486: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-16 11:19:18.217752: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-16 11:19:18.217977: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:939] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-16 11:19:18.218159: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4835 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1060 6GB, pci bus id: 0000:07:00.0, compute capability: 6.1

# %% [markdown]
# - Passo 1: THE FIRST CONVOLUTIONAL LAYER #1
#   - Input = 32x32x1
#   - Output = 28x28x6
#   - Output = (Input-filter+1)/Stride\* => (32-5+1)/1=28
#   - Used a 5x5 Filter with input depth of 3 and output depth of 6
#   - Apply a RELU Activation function to the output
#   - pooling for input, Input = 28x28x6 and Output = 14x14x6

# %%
LeNet.add(layers.Conv2D(6, (5, 5), activation='relu', input_shape=(32, 32, 1)))
LeNet.add(layers.AveragePooling2D())

# %% [markdown]
# - STEP 2: THE SECOND CONVOLUTIONAL LAYER #2
#   - Input = 14x14x6
#   - Output = 10x10x16
#   - Layer 2: Convolutional layer with Output = 10x10x16
#   - Output = (Input-filter+1)/strides => 10 = 14-5+1/1
#   - Apply a RELU Activation function to the output
#   - Pooling with Input = 10x10x16 and Output = 5x5x16

# %%
LeNet.add(layers.Conv2D(16, (5, 5), activation='relu'))
LeNet.add(layers.AveragePooling2D())

# %% [markdown]
# - STEP 3: FLATTENING THE NETWORK
#   - Flatten the network with Input = 5x5x16 and Output = 400

# %%
LeNet.add(layers.Flatten())

# %% [markdown]
# - STEP 4: FULLY CONNECTED LAYER
#   - Layer 3: Fully Connected layer with Input = 400 and Output = 120
#   - Apply a RELU Activation function to the output

# %%
LeNet.add(layers.Dense(120, activation='relu'))

# %% [markdown]
# - STEP 5: ANOTHER FULLY CONNECTED LAYER
#   - Layer 4: Fully Connected Layer with Input = 120 and Output = 84
#   - Apply a RELU Activation function to the output

# %%
LeNet.add(layers.Dense(84, activation='relu'))

# %% [markdown]
# - STEP 6: FULLY CONNECTED LAYER
#   - Layer 5: Fully Connected layer with Input = 84 and Output = 43

# %%
LeNet.add(layers.Dense(43, activation='softmax'))

# %%
LeNet.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 6)         156
#
#  average_pooling2d (AverageP  (None, 14, 14, 6)        0
#  ooling2D)
#
#  conv2d_1 (Conv2D)           (None, 10, 10, 16)        2416
#
#  average_pooling2d_1 (Averag  (None, 5, 5, 16)         0
#  ePooling2D)
#
#  flatten (Flatten)           (None, 400)               0
#
#  dense (Dense)               (None, 120)               48120
#
#  dense_1 (Dense)             (None, 84)                10164
#
#  dense_2 (Dense)             (None, 43)                3655
#
# =================================================================
# Total params: 64,511
# Trainable params: 64,511
# Non-trainable params: 0
# _________________________________________________________________

# %%
LeNet.compile(optimizer='Adam', loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# %%time
history = LeNet.fit(X_train_gray_norm, y_train,
                    batch_size=500,
                    epochs=50,
                    validation_data=(X_validation_gray_norm, y_validation))
# Out:
# Epoch 1/50
# 70/70 [==============================] - 2s 10ms/step - loss: 3.2735 - accuracy: 0.1544 - val_loss: 2.9446 - val_accuracy: 0.2345
# Epoch 2/50
# 70/70 [==============================] - 0s 7ms/step - loss: 1.8502 - accuracy: 0.4837 - val_loss: 1.6193 - val_accuracy: 0.5215
# Epoch 3/50
# 70/70 [==============================] - 0s 7ms/step - loss: 1.0248 - accuracy: 0.7038 - val_loss: 1.1507 - val_accuracy: 0.6483
# Epoch 4/50
# 70/70 [==============================] - 0s 6ms/step - loss: 0.7152 - accuracy: 0.7953 - val_loss: 0.8568 - val_accuracy: 0.7519
# Epoch 5/50
# 70/70 [==============================] - 0s 7ms/step - loss: 0.5456 - accuracy: 0.8468 - val_loss: 0.8092 - val_accuracy: 0.7592
# Epoch 6/50
# 70/70 [==============================] - 0s 7ms/step - loss: 0.4550 - accuracy: 0.8742 - val_loss: 0.6943 - val_accuracy: 0.8039
# Epoch 7/50
# 70/70 [==============================] - 0s 6ms/step - loss: 0.3932 - accuracy: 0.8914 - val_loss: 0.6793 - val_accuracy: 0.7975
# Epoch 8/50
# 70/70 [==============================] - 0s 6ms/step - loss: 0.3342 - accuracy: 0.9111 - val_loss: 0.6400 - val_accuracy: 0.8209
# Epoch 9/50
# 70/70 [==============================] - 0s 6ms/step - loss: 0.2926 - accuracy: 0.9231 - val_loss: 0.6897 - val_accuracy: 0.8023
# Epoch 10/50
# 70/70 [==============================] - 0s 6ms/step - loss: 0.2708 - accuracy: 0.9286 - val_loss: 0.5904 - val_accuracy: 0.8381
# Epoch 11/50
# 70/70 [==============================] - 0s 6ms/step - loss: 0.2381 - accuracy: 0.9386 - val_loss: 0.5877 - val_accuracy: 0.8290
# Epoch 12/50
# 70/70 [==============================] - 0s 7ms/step - loss: 0.2158 - accuracy: 0.9446 - val_loss: 0.5739 - val_accuracy: 0.8354
# Epoch 13/50
# 70/70 [==============================] - 0s 7ms/step - loss: 0.1976 - accuracy: 0.9493 - val_loss: 0.5889 - val_accuracy: 0.8429
# Epoch 14/50
# 70/70 [==============================] - 0s 7ms/step - loss: 0.1772 - accuracy: 0.9550 - val_loss: 0.5837 - val_accuracy: 0.8433
# Epoch 15/50
# 70/70 [==============================] - 0s 6ms/step - loss: 0.1624 - accuracy: 0.9604 - val_loss: 0.6451 - val_accuracy: 0.8270
# Epoch 16/50
# 70/70 [==============================] - 0s 6ms/step - loss: 0.1559 - accuracy: 0.9593 - val_loss: 0.5919 - val_accuracy: 0.8467
# Epoch 17/50
# 70/70 [==============================] - 0s 6ms/step - loss: 0.1407 - accuracy: 0.9643 - val_loss: 0.5574 - val_accuracy: 0.8512
# Epoch 18/50
# 70/70 [==============================] - 0s 6ms/step - loss: 0.1319 - accuracy: 0.9670 - val_loss: 0.6102 - val_accuracy: 0.8449
# Epoch 19/50
# 70/70 [==============================] - 0s 6ms/step - loss: 0.1181 - accuracy: 0.9706 - val_loss: 0.5885 - val_accuracy: 0.8476
# Epoch 20/50
# 70/70 [==============================] - 0s 6ms/step - loss: 0.1122 - accuracy: 0.9721 - val_loss: 0.5846 - val_accuracy: 0.8485
# Epoch 21/50
# 70/70 [==============================] - 0s 6ms/step - loss: 0.1047 - accuracy: 0.9740 - val_loss: 0.6293 - val_accuracy: 0.8587
# Epoch 22/50
# 70/70 [==============================] - 0s 6ms/step - loss: 0.0944 - accuracy: 0.9769 - val_loss: 0.6591 - val_accuracy: 0.8429
# Epoch 23/50
# 70/70 [==============================] - 0s 7ms/step - loss: 0.0943 - accuracy: 0.9763 - val_loss: 0.6422 - val_accuracy: 0.8506
# Epoch 24/50
# 70/70 [==============================] - 0s 6ms/step - loss: 0.0848 - accuracy: 0.9794 - val_loss: 0.6070 - val_accuracy: 0.8510
# Epoch 25/50
# 70/70 [==============================] - 0s 6ms/step - loss: 0.0817 - accuracy: 0.9788 - val_loss: 0.6576 - val_accuracy: 0.8535
# Epoch 26/50
# 70/70 [==============================] - 0s 6ms/step - loss: 0.0723 - accuracy: 0.9819 - val_loss: 0.6612 - val_accuracy: 0.8553
# Epoch 27/50
# 70/70 [==============================] - 0s 6ms/step - loss: 0.0691 - accuracy: 0.9826 - val_loss: 0.6462 - val_accuracy: 0.8617
# Epoch 28/50
# 70/70 [==============================] - 0s 6ms/step - loss: 0.0603 - accuracy: 0.9861 - val_loss: 0.6859 - val_accuracy: 0.8515
# Epoch 29/50
# 70/70 [==============================] - 0s 6ms/step - loss: 0.0650 - accuracy: 0.9841 - val_loss: 0.6833 - val_accuracy: 0.8612
# Epoch 30/50
# 70/70 [==============================] - 0s 7ms/step - loss: 0.0572 - accuracy: 0.9862 - val_loss: 0.6967 - val_accuracy: 0.8508
# Epoch 31/50
# 70/70 [==============================] - 0s 6ms/step - loss: 0.0544 - accuracy: 0.9866 - val_loss: 0.6894 - val_accuracy: 0.8583
# Epoch 32/50
# 70/70 [==============================] - 0s 7ms/step - loss: 0.0475 - accuracy: 0.9887 - val_loss: 0.7018 - val_accuracy: 0.8571
# Epoch 33/50
# 70/70 [==============================] - 0s 6ms/step - loss: 0.0457 - accuracy: 0.9887 - val_loss: 0.8046 - val_accuracy: 0.8528
# Epoch 34/50
# 70/70 [==============================] - 0s 6ms/step - loss: 0.0520 - accuracy: 0.9863 - val_loss: 0.7500 - val_accuracy: 0.8590
# Epoch 35/50
# 70/70 [==============================] - 0s 6ms/step - loss: 0.0446 - accuracy: 0.9891 - val_loss: 0.7533 - val_accuracy: 0.8424
# Epoch 36/50
# 70/70 [==============================] - 0s 6ms/step - loss: 0.0440 - accuracy: 0.9882 - val_loss: 0.7234 - val_accuracy: 0.8499
# Epoch 37/50
# 70/70 [==============================] - 0s 6ms/step - loss: 0.0354 - accuracy: 0.9920 - val_loss: 0.7176 - val_accuracy: 0.8605
# Epoch 38/50
# 70/70 [==============================] - 0s 6ms/step - loss: 0.0436 - accuracy: 0.9882 - val_loss: 0.6682 - val_accuracy: 0.8683
# Epoch 39/50
# 70/70 [==============================] - 0s 7ms/step - loss: 0.0347 - accuracy: 0.9912 - val_loss: 0.7948 - val_accuracy: 0.8578
# Epoch 40/50
# 70/70 [==============================] - 0s 7ms/step - loss: 0.0322 - accuracy: 0.9919 - val_loss: 0.7534 - val_accuracy: 0.8676
# Epoch 41/50
# 70/70 [==============================] - 0s 6ms/step - loss: 0.0293 - accuracy: 0.9930 - val_loss: 0.8340 - val_accuracy: 0.8633
# Epoch 42/50
# 70/70 [==============================] - 0s 6ms/step - loss: 0.0313 - accuracy: 0.9918 - val_loss: 0.7605 - val_accuracy: 0.8696
# Epoch 43/50
# 70/70 [==============================] - 0s 7ms/step - loss: 0.0300 - accuracy: 0.9915 - val_loss: 0.6981 - val_accuracy: 0.8615
# Epoch 44/50
# 70/70 [==============================] - 0s 6ms/step - loss: 0.0291 - accuracy: 0.9918 - val_loss: 0.7821 - val_accuracy: 0.8660
# Epoch 45/50
# 70/70 [==============================] - 0s 6ms/step - loss: 0.0272 - accuracy: 0.9927 - val_loss: 0.8874 - val_accuracy: 0.8463
# Epoch 46/50
# 70/70 [==============================] - 0s 6ms/step - loss: 0.0258 - accuracy: 0.9933 - val_loss: 0.8118 - val_accuracy: 0.8667
# Epoch 47/50
# 70/70 [==============================] - 1s 7ms/step - loss: 0.0263 - accuracy: 0.9924 - val_loss: 0.7845 - val_accuracy: 0.8669
# Epoch 48/50
# 70/70 [==============================] - 0s 6ms/step - loss: 0.0268 - accuracy: 0.9924 - val_loss: 0.8447 - val_accuracy: 0.8603
# Epoch 49/50
# 70/70 [==============================] - 0s 6ms/step - loss: 0.0288 - accuracy: 0.9919 - val_loss: 0.9144 - val_accuracy: 0.8544
# Epoch 50/50
# 70/70 [==============================] - 0s 6ms/step - loss: 0.0213 - accuracy: 0.9943 - val_loss: 0.8540 - val_accuracy: 0.8599
# CPU times: user 28.2 s, sys: 1.31 s, total: 29.6 s
# Wall time: 24 s

# %% [markdown]
# # Etapa 6: Avaliação do modelo

# %%
score = LeNet.evaluate(X_test_gray_norm, y_test)
print('Test Accuracy: {}'.format(score[1]))
# Out:
# 395/395 [==============================] - 1s 2ms/step - loss: 1.4115 - accuracy: 0.8542
# Test Accuracy: 0.8541567921638489

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
accuracy
# Out:
# [0.15437224507331848,
#  0.4837208092212677,
#  0.7037558555603027,
#  0.7953101992607117,
#  0.8468059301376343,
#  0.8742205500602722,
#  0.8914336562156677,
#  0.911146879196167,
#  0.9231012463569641,
#  0.9286186099052429,
#  0.9386476874351501,
#  0.9445673823356628,
#  0.9493376016616821,
#  0.9549987316131592,
#  0.9603724479675293,
#  0.9593091607093811,
#  0.9642518758773804,
#  0.9670392870903015,
#  0.9705738425254822,
#  0.972068190574646,
#  0.9739647507667542,
#  0.9769245982170105,
#  0.9763211607933044,
#  0.9794247150421143,
#  0.9787637591362,
#  0.9818673133850098,
#  0.9826144576072693,
#  0.9861202836036682,
#  0.9841087460517883,
#  0.9862064719200134,
#  0.986637532711029,
#  0.9887065887451172,
#  0.9887353181838989,
#  0.9863214492797852,
#  0.989137589931488,
#  0.9881605505943298,
#  0.9919537901878357,
#  0.9882467985153198,
#  0.9912353754043579,
#  0.9918676018714905,
#  0.9930170178413391,
#  0.9918100833892822,
#  0.9914652705192566,
#  0.9918100833892822,
#  0.9927009344100952,
#  0.993304431438446,
#  0.9924423098564148,
#  0.9923561215400696,
#  0.991925060749054,
#  0.9942526817321777]

# %%
epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'bo', color='r', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
# Out:
# /tmp/ipykernel_5300/1936345582.py:2: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "bo" (-> color='b'). The keyword argument will take precedence.
#   plt.plot(epochs, accuracy, 'bo', color='r', label='Training Accuracy')

# %%
plt.plot(epochs, loss, 'ro', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and Validation loss')
plt.legend()

# %%
predicted_classes = np.argmax(LeNet.predict(X_test_gray_norm), axis=1)

y_true = y_test

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_true, predicted_classes)
plt.figure(figsize=(25, 25))
sns.heatmap(cm, annot=True)
# Out:
# <AxesSubplot:>

# %%
L = 7
W = 7

fig, axes = plt.subplots(L, W, figsize=(12, 12))
axes = axes.ravel()

for i in np.arange(0, L*W):
    axes[i].imshow(X_test[i])
    axes[i].set_title('Prediction = {}\n True = {}'.format(
        predicted_classes[i], y_true[i]))
    axes[i].axis('off')

plt.subplots_adjust(wspace=1)
